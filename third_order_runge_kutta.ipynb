# %%
import numpy as np
import pandas as pd

from decimal import *
getcontext().prec = 100

# %%
xi = None
yi = None

k1 = None
k2 = None
k3 = None

global h1
h1 = 0.25

decimal_places = '0.000001'

x_range = 5

# %%
def given_func(x, y):
    x = Decimal(str(x)).quantize(Decimal(decimal_places), rounding=ROUND_HALF_UP)
    y = Decimal(str(y)).quantize(Decimal(decimal_places), rounding=ROUND_HALF_UP)
    
    return Decimal(str(y*(x**Decimal('2')) - Decimal('1.1')*y)).quantize(Decimal(decimal_places), rounding=ROUND_HALF_UP)


def method_func(yi, k1, k2, k3, h=h1):
    yi = Decimal(str(yi)).quantize(Decimal(decimal_places), rounding=ROUND_HALF_UP)
    k1 = Decimal(str(k1)).quantize(Decimal(decimal_places), rounding=ROUND_HALF_UP)
    k2 = Decimal(str(k2)).quantize(Decimal(decimal_places), rounding=ROUND_HALF_UP)
    k3 = Decimal(str(k3)).quantize(Decimal(decimal_places), rounding=ROUND_HALF_UP)
    
    h = Decimal(str(h)).quantize(Decimal(decimal_places), rounding=ROUND_HALF_UP)
    
    return Decimal(str(yi + Decimal(1/6)*(k1 + Decimal(4)*(k2) + k3)*h)).quantize(Decimal(decimal_places), rounding=ROUND_HALF_UP)

def return_k1(xi, yi):
    return given_func(xi, yi)

def return_k2(xi, yi, k1, h=h1): 
    xi = Decimal(str(xi)).quantize(Decimal(decimal_places), rounding=ROUND_HALF_UP)
    yi = Decimal(str(yi)).quantize(Decimal(decimal_places), rounding=ROUND_HALF_UP)
    k1 = Decimal(str(k1)).quantize(Decimal(decimal_places), rounding=ROUND_HALF_UP)
    h = Decimal(str(h)).quantize(Decimal(decimal_places), rounding=ROUND_HALF_UP)
    
    x = xi + Decimal(1/2)*(h)
    y = yi + (Decimal(1/2)*(k1)*(h))
    
    return given_func(x, y)

def return_k3(xi, yi, k1, k2, h=h1):
    xi = Decimal(str(xi)).quantize(Decimal(decimal_places), rounding=ROUND_HALF_UP)
    yi = Decimal(str(yi)).quantize(Decimal(decimal_places), rounding=ROUND_HALF_UP)
    k1 = Decimal(str(k1)).quantize(Decimal(decimal_places), rounding=ROUND_HALF_UP)
    k2 = Decimal(str(k2)).quantize(Decimal(decimal_places), rounding=ROUND_HALF_UP)
    h = Decimal(str(h)).quantize(Decimal(decimal_places), rounding=ROUND_HALF_UP)
    
    x = xi + h
    y = yi - k1*h + Decimal('2')*k2*h
    
    return given_func(x,y)

# %%
# appending x values to array
list_x = []
i = 0
while i <= x_range:
    list_x.append(i)
    i+=h1


data_arr = np.zeros((len(list_x), 1), dtype=np.float64)
data_arr[:,0] = np.transpose(list_x)

# %%
# making y values
list_y = [1]
list_k1 = [0]
list_k2 = [0]
list_k3 = [0]

# %%
for i in range(len(list_x) - 1):
    k1 = return_k1(list_x[i], list_y[i])
    k2 = return_k2(list_x[i], list_y[i], k1)
    k3 = return_k3(list_x[i], list_y[i], k1, k2)
    
    yi = method_func(list_y[i], k1, k2, k3)
    
    list_y.append(yi)
    list_k1.append(k1)
    list_k2.append(k2)
    list_k3.append(k3)


data_arr = np.append(data_arr, np.transpose([list_y]), axis=1)
data_arr = np.append(data_arr, np.transpose([list_k1]), axis=1)
data_arr = np.append(data_arr, np.transpose([list_k2]), axis=1)
data_arr = np.append(data_arr, np.transpose([list_k3]), axis=1)

# %%
df = pd.DataFrame(data_arr, columns=['x', 'y', 'k1', 'k2', 'k3'])
df
# Out:
#        x                     y                    k1                    k2  \
# 0    0.0                     1                     0                     0
# 1   0.25              0.763386             -1.100000             -0.935273
# 2    0.5              0.601391             -0.792013             -0.637393
# 3   0.75              0.504483             -0.511182             -0.381284
# 4    1.0              0.464903             -0.271160             -0.157353
# 5   1.25              0.485554             -0.046490              0.076037
# 6    1.5              0.592897              0.224569              0.406085
# 7   1.75              0.872687              0.681832              1.044738
# 8    2.0              1.593905              1.712648              2.625224
# 9   2.25              3.707501              4.622325              7.417699
# 10   2.5             11.223340             14.690973             25.172648
# 11  2.75             44.950190             57.800201            106.827564
# 12   3.0            240.828525            290.490603            582.289543
# 13  3.25           1736.491747           1902.545348           4147.772758
# 14   3.5          16881.179023          16431.553156          39005.954351
# 15  3.75         220913.226799         188225.146106         486553.496150
# 16   4.0        3875939.258977        2863587.702382        8055222.199298
# 17  4.25       90649162.989355       57751494.958757      176581887.887783
# 18   4.5     2806625350.828960     1537636427.206934     5102857827.252349
# 19  4.75   114168132126.463400    53746875468.374584   193267894390.474872
# 20   5.0  6053395840090.706471  2450333535764.220723  9529984700548.361408
#
#                         k3
# 0                        0
# 1                -0.837640
# 2                -0.546289
# 3                -0.289468
# 4                -0.049360
# 5                 0.237977
# 6                 0.727322
# 7                 1.854186
# 8                 5.095697
# 9                16.433173
# 10               64.998572
# 11              324.333953
# 12             2081.431257
# 13            17402.280940
# 14           191017.124069
# 15          2762330.015915
# 16         52636148.272710
# 17       1318478323.019174
# 18      43234360771.934193
# 19    1845857709584.952647
# 20  101971192653184.175260
